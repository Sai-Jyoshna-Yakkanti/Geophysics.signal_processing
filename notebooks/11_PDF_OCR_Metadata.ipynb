# %% [markdown]
# # OCR & Metadata Extraction from a Seismic Report (PDF)
#
# In this notebook, I demonstrate how to extract structured data and images from a real seismic report in PDF format using OCR techniques. This is part of a broader geophysics pipeline aimed at enabling large-scale, automated analysis of seismic literature and field reports.
#
# Key skills demonstrated:
# - Text and image extraction from complex PDFs
# - OCR using Tesseract and PyMuPDF
# - Structuring raw OCR output for downstream processing

# %%
import fitz              # PyMuPDF
import pytesseract
from PIL import Image
import cv2
import numpy as np
import os

# Set up path to tesseract executable (needed on Windows)
pytesseract.pytesseract.tesseract_cmd = r"C:\Program Files\Tesseract-OCR\tesseract.exe"

# %%
#loading pdf with page count preview
pdf_path = "data_report.pdf"

# Load the PDF
pdf_path = "../data_report.pdf"

doc = fitz.open(pdf_path)

print(f" PDF loaded: {pdf_path}")
print(f" Number of pages: {len(doc)}")
# Out:
#  PDF loaded: ../data_report.pdf
#  Number of pages: 10

# %%
for page_num in range(len(doc)):
    text = doc[page_num].get_text()
    print(f"\n--- Page {page_num+1} ---\n{text[:1000]}")  # Only show first 1000 chars for brevity
# Out:
# --- Page 1 ---
# Magnitude 7.0 NEW CALEDONIA
# Thursday,  March 31, 2022, 05:44:01 UTC
# A magnitude 7.0 earthquake has occurred 279 km (173 miles) ESE of
# Tadine, New Caledonia at a depth of 10 km (6.2 miles). A tsunami warning
# issued for the region has been lifted. There are no immediate reports of
# damage or injuries.
# Australia
# Yédjélé Beach, Maré, New Caledonia
#
#
# --- Page 2 ---
# Extreme
# Violent
# Severe
# Very Strong
# Strong
# Moderate
# Light
# Weak
# Not Felt
# USGS estimated shaking intensity from M 7.0 Earthquake
# The Modified-Mercalli Intensity
# (MMI) scale is a ten-stage
# scale, from I to X, that indicates
# the severity of ground shaking.
# Intensity is based on observed
# effects and is variable over the
# area affected by an earthquake.
# Intensity is dependent on
# earthquake size, depth,
# distance, and local conditions.
# MMI   Perceived Shaking
# Magnitude 7.0 NEW CALEDONIA
# Thursday,  March 31, 2022, 05:44:01 UTC
#
#
# --- Page 3 ---
# The USGS PAGER map shows the
# population exposed to different Modified
# Mercalli Intensity (MMI) levels.
# The USGS estimates that over 3,000
# people felt light shaking from this
# earthquake.
# Image courtesy of the US Geological Survey
# The color-coded contour lines outline regions of MMI intensity.
# The total population exposure to a given MMI value is obtained by
# summing the population between the contour lines. The estimated
# population exposure to each MMI Intensity is shown in the table.
# Magnitude 7.0 NEW CALEDONIA
# Thursday,  March 31, 2022, 05:44:01 UTC
#
#
# --- Page 4 ---
# This seismicity map shows
# the most recent 2000
# earthquakes in the region of
# the South New Hebrides and
# Tonga trenches. Earthquake
# depths increase from west to
# east across the South New
# Hebrides Trench, where the
# Australian Plate subducts
# beneath the Pacific Plate.
# Across the Tonga Trench,
# earthquake depths increase
# from east to west where the
# Pacific Plate subducts
# beneath the Australian Plate.
# The epicenter of this M7.0
# earthquake is labeled on the
# inset map at right.
# Pacific
# Plate
# Maps created with the
# IRIS Earthquake Browser
# South New Hebrides Trench
# Australian
# Plate
# M7.0 Earthquake
# Magnitude 7.0 NEW CALEDONIA
# Thursday,  March 31, 2022, 05:44:01 UTC
#
#
# --- Page 5 ---
# This regional map shows the complexity of major tectonic plates and microplates resulting
# from the convergence between the Australian and Pacific Plates.  The red star indicates the
# epicenter of this earthquake. The location and focal mechanism indicate that this earthquake
# resulted from thrust faulting on or near the boundary between the subducting Australian Plate
# and the overriding Pacific Plate in the subduction zone at the South New Hebrides Trench.
# Magnitude 7.0 NEW CALEDONIA
# Thursday,  March 31, 2022, 05:44:01 UTC
#
#
# --- Page 6 ---
# This short animation is part of a
# longer IRIS animation that looks
# at seismicity and tectonics of
# Australian – Pacific Plate
# interactions immediately to the
# northwest of this earthquake
# The animation examines three
# cross sections from southeast
# to northwest that reveal a
# change from:
# 1.
# Steeply-dipping subduction
# along the New Hebrides
# trench to
# 2.
# Strike-slip motion along the
# Solomon Islands to
# 3.
# Shallow-dipping subduction
# farther to the west.
# Full animation:  https://youtu.be/GUIPv1vUvlc
# Or download:  https://www.iris.edu/hq/inclass/animation/237
# Magnitude 7.0 NEW CALEDONIA
# Thursday,  March 31, 2022, 05:44:01 UTC
#
#
# --- Page 7 ---
# USGS WPhase Centroid Moment Tensor Solution
# The focal mechanism is how seismologists plot the 3-D stress orientations of an
# earthquake. Because an earthquake occurs as slip on a fault, it generates
# primary (P) waves in quadrants where the first pulse is compressional (shaded)
# and quadrants where the first pulse is extensional (white). The orientation of
# these quadrants determined from recorded seismic waves identifies the type of
# fault that produced the earthquake.
# The earthquake occurred as the result of reverse faulting on or near the plate
# boundary interface between the Australian Plate and the Pacific Plate.
# Magnitude 7.0 NEW CALEDONIA
# Thursday,  March 31, 2022, 05:44:01 UTC
#
#
# --- Page 8 ---
# This animation explores the motion of
# a reverse fault, and how reverse faults
# are represented in a focal mechanism.
# USGS W-phase Moment Tensor Solution
# Magnitude 7.0 NEW CALEDONIA
# Thursday,  March 31, 2022, 05:44:01 UTC
# Remember, this was the focal mechanism
# solution for this earthquake.  It was estimated
# by analysis of the pattern of "first motions",
# that is, whether the first-arriving P waves
# push up or pull down.
#
#
# --- Page 9 ---
# With instrumental noise from early spring weather and the great distance to this magnitude
# 7.0 earthquake, picking arrivals of seismic waves on this seismogram is a challenge.
# S
# The first seismic waves to arrive from this earthquake were the compressional
# P waves.  Following the earthquake, it took 13 minutes and 6 seconds for the
# P waves to travel a curved path through the mantle to Bend, Oregon.
# Surface Waves
# The record of the earthquake in Bend, Oregon (BNOR) is illustrated below.
# Bend is 10,143 km (6,303 miles, 91.4°) from the location of this earthquake.
# P
# S waves are shear waves that follow the same path through the mantle as P waves.
# S waves took 24 minutes and 6 seconds to travel from the earthquake to Bend.
# Surface waves traveled the 10,143 km (6,303 miles) along the perimeter
# of the Earth from the earthquake to the recording seismometer.
# Magnitude 7.0 NEW CALEDONIA
# Thursday,  March 31, 2022, 05:44:01 UTC
#
#
# --- Page 10 ---
# Teachable Moments are a service of
# The Incorporated Research Institutions for Seismology
# Education & Public Outreach
# and
# The University of Portland
# Please send feedback to tkb@iris.edu
# To receive automatic notifications of new Teachable Moments
# subscribe at www.iris.edu/hq/retm
# www.iris.edu/earthquake

# %%
img_dir = "../output/images"
os.makedirs(img_dir, exist_ok=True)

image_paths = []  # list of (page, image_path)

for i in range(len(doc)):
    for img_index, img_info in enumerate(doc.get_page_images(i), start=1):
        xref = img_info[0]
        base_image = doc.extract_image(xref)
        img_bytes = base_image["image"]
        img_ext = base_image["ext"]
        img_path = os.path.join(img_dir, f"page{i+1}_img{img_index}.{img_ext}")
        with open(img_path, "wb") as img_file:
            img_file.write(img_bytes)
        image_paths.append((i+1, img_path))
        print(f" Saved image from page {i+1}: {img_path}")
# Out:
#  Saved image from page 1: ../output/images\page1_img1.png
#  Saved image from page 1: ../output/images\page1_img2.png
#  Saved image from page 1: ../output/images\page1_img3.png
#  Saved image from page 1: ../output/images\page1_img4.png
#  Saved image from page 1: ../output/images\page1_img5.png
#  Saved image from page 1: ../output/images\page1_img6.png
#  Saved image from page 1: ../output/images\page1_img7.jpeg
#  Saved image from page 1: ../output/images\page1_img8.jpeg
#  Saved image from page 1: ../output/images\page1_img9.png
#  Saved image from page 1: ../output/images\page1_img10.png
#  Saved image from page 1: ../output/images\page1_img11.png
#  Saved image from page 1: ../output/images\page1_img12.png
#  Saved image from page 1: ../output/images\page1_img13.png
#  Saved image from page 1: ../output/images\page1_img14.png
#  Saved image from page 1: ../output/images\page1_img15.png
#  Saved image from page 1: ../output/images\page1_img16.png
#  Saved image from page 1: ../output/images\page1_img17.png
#  Saved image from page 2: ../output/images\page2_img1.png
#  Saved image from page 2: ../output/images\page2_img2.jpeg
#  Saved image from page 2: ../output/images\page2_img3.png
#  Saved image from page 2: ../output/images\page2_img4.png
#  Saved image from page 2: ../output/images\page2_img5.png
#  Saved image from page 2: ../output/images\page2_img6.png
#  Saved image from page 2: ../output/images\page2_img7.png
#  Saved image from page 2: ../output/images\page2_img8.png
#  Saved image from page 2: ../output/images\page2_img9.jpeg
#  Saved image from page 2: ../output/images\page2_img10.png
#  Saved image from page 2: ../output/images\page2_img11.png
#  Saved image from page 2: ../output/images\page2_img12.png
#  Saved image from page 2: ../output/images\page2_img13.png
#  Saved image from page 2: ../output/images\page2_img14.png
#  Saved image from page 2: ../output/images\page2_img15.png
#  Saved image from page 2: ../output/images\page2_img16.png
#  Saved image from page 3: ../output/images\page3_img1.png
#  Saved image from page 3: ../output/images\page3_img2.jpeg
#  Saved image from page 3: ../output/images\page3_img3.png
#  Saved image from page 3: ../output/images\page3_img4.png
#  Saved image from page 3: ../output/images\page3_img5.png
#  Saved image from page 3: ../output/images\page3_img6.png
#  Saved image from page 3: ../output/images\page3_img7.png
#  Saved image from page 3: ../output/images\page3_img8.png
#  Saved image from page 3: ../output/images\page3_img9.png
#  Saved image from page 3: ../output/images\page3_img10.png
#  Saved image from page 3: ../output/images\page3_img11.png
#  Saved image from page 3: ../output/images\page3_img12.png
#  Saved image from page 3: ../output/images\page3_img13.png
#  Saved image from page 3: ../output/images\page3_img14.png
#  Saved image from page 3: ../output/images\page3_img15.png
#  Saved image from page 3: ../output/images\page3_img16.png
#  Saved image from page 4: ../output/images\page4_img1.jpeg
#  Saved image from page 4: ../output/images\page4_img2.png
#  Saved image from page 4: ../output/images\page4_img3.png
#  Saved image from page 4: ../output/images\page4_img4.png
#  Saved image from page 4: ../output/images\page4_img5.png
#  Saved image from page 4: ../output/images\page4_img6.png
#  Saved image from page 4: ../output/images\page4_img7.png
#  Saved image from page 4: ../output/images\page4_img8.png
#  Saved image from page 4: ../output/images\page4_img9.png
#  Saved image from page 4: ../output/images\page4_img10.png
#  Saved image from page 4: ../output/images\page4_img11.png
#  Saved image from page 4: ../output/images\page4_img12.jpeg
#  Saved image from page 4: ../output/images\page4_img13.jpeg
#  Saved image from page 4: ../output/images\page4_img14.png
#  Saved image from page 4: ../output/images\page4_img15.jpeg
#  Saved image from page 4: ../output/images\page4_img16.png
#  Saved image from page 4: ../output/images\page4_img17.png
#  Saved image from page 4: ../output/images\page4_img18.png
#  Saved image from page 4: ../output/images\page4_img19.png
#  Saved image from page 5: ../output/images\page5_img1.png
#  Saved image from page 5: ../output/images\page5_img2.jpeg
#  Saved image from page 5: ../output/images\page5_img3.png
#  Saved image from page 5: ../output/images\page5_img4.png
#  Saved image from page 5: ../output/images\page5_img5.png
#  Saved image from page 5: ../output/images\page5_img6.png
#  Saved image from page 5: ../output/images\page5_img7.png
#  Saved image from page 5: ../output/images\page5_img8.png
#  Saved image from page 5: ../output/images\page5_img9.png
#  Saved image from page 5: ../output/images\page5_img10.png
#  Saved image from page 5: ../output/images\page5_img11.png
#  Saved image from page 5: ../output/images\page5_img12.png
#  Saved image from page 5: ../output/images\page5_img13.png
#  Saved image from page 5: ../output/images\page5_img14.png
#  Saved image from page 5: ../output/images\page5_img15.png
#  Saved image from page 6: ../output/images\page6_img1.png
#  Saved image from page 6: ../output/images\page6_img2.png
#  Saved image from page 6: ../output/images\page6_img3.png
#  Saved image from page 6: ../output/images\page6_img4.png
#  Saved image from page 6: ../output/images\page6_img5.png
#  Saved image from page 6: ../output/images\page6_img6.png
#  Saved image from page 6: ../output/images\page6_img7.png
#  Saved image from page 6: ../output/images\page6_img8.png
#  Saved image from page 6: ../output/images\page6_img9.png
#  Saved image from page 6: ../output/images\page6_img10.png
#  Saved image from page 6: ../output/images\page6_img11.png
#  Saved image from page 6: ../output/images\page6_img12.png
#  Saved image from page 6: ../output/images\page6_img13.png
#  Saved image from page 6: ../output/images\page6_img14.png
#  Saved image from page 7: ../output/images\page7_img1.png
#  Saved image from page 7: ../output/images\page7_img2.png
#  Saved image from page 7: ../output/images\page7_img3.png
#  Saved image from page 7: ../output/images\page7_img4.png
#  Saved image from page 7: ../output/images\page7_img5.png
#  Saved image from page 7: ../output/images\page7_img6.png
#  Saved image from page 7: ../output/images\page7_img7.png
#  Saved image from page 7: ../output/images\page7_img8.png
#  Saved image from page 7: ../output/images\page7_img9.jpeg
#  Saved image from page 7: ../output/images\page7_img10.png
#  Saved image from page 7: ../output/images\page7_img11.png
#  Saved image from page 7: ../output/images\page7_img12.png
#  Saved image from page 7: ../output/images\page7_img13.png
#  Saved image from page 7: ../output/images\page7_img14.png
#  Saved image from page 7: ../output/images\page7_img15.png
#  Saved image from page 7: ../output/images\page7_img16.png
#  Saved image from page 7: ../output/images\page7_img17.png
#  Saved image from page 8: ../output/images\page8_img1.png
#  Saved image from page 8: ../output/images\page8_img2.png
#  Saved image from page 8: ../output/images\page8_img3.png
#  Saved image from page 8: ../output/images\page8_img4.png
#  Saved image from page 8: ../output/images\page8_img5.png
#  Saved image from page 8: ../output/images\page8_img6.png
#  Saved image from page 8: ../output/images\page8_img7.jpeg
#  Saved image from page 8: ../output/images\page8_img8.png
#  Saved image from page 8: ../output/images\page8_img9.png
#  Saved image from page 8: ../output/images\page8_img10.png
#  Saved image from page 8: ../output/images\page8_img11.png
#  Saved image from page 8: ../output/images\page8_img12.png
#  Saved image from page 8: ../output/images\page8_img13.png
#  Saved image from page 8: ../output/images\page8_img14.png
#  Saved image from page 8: ../output/images\page8_img15.png
#  Saved image from page 9: ../output/images\page9_img1.png
#  Saved image from page 9: ../output/images\page9_img2.png
#  Saved image from page 9: ../output/images\page9_img3.png
#  Saved image from page 9: ../output/images\page9_img4.png
#  Saved image from page 9: ../output/images\page9_img5.png
#  Saved image from page 9: ../output/images\page9_img6.png
#  Saved image from page 9: ../output/images\page9_img7.png
#  Saved image from page 9: ../output/images\page9_img8.png
#  Saved image from page 9: ../output/images\page9_img9.png
#  Saved image from page 9: ../output/images\page9_img10.png
#  Saved image from page 9: ../output/images\page9_img11.png
#  Saved image from page 9: ../output/images\page9_img12.png
#  Saved image from page 9: ../output/images\page9_img13.png
#  Saved image from page 9: ../output/images\page9_img14.png
#  Saved image from page 9: ../output/images\page9_img15.png
#  Saved image from page 10: ../output/images\page10_img1.png
#  Saved image from page 10: ../output/images\page10_img2.jpeg
#  Saved image from page 10: ../output/images\page10_img3.png

# %% [markdown]
# extracted embedded images above and
# Next, I run Tesseract OCR on each extracted image to capture any text labels, map legends, or captions that aren’t in the PDF’s text stream.

# %%
ocr_results = {}  # page → [ocr_texts]

for page_num, img_path in image_paths:
    # Read image with OpenCV
    img = cv2.imread(img_path)
    # Convert to RGB for PIL
    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    pil_img = Image.fromarray(img_rgb)
    # OCR
    text = pytesseract.image_to_string(pil_img)
    ocr_results.setdefault(page_num, []).append(text)
    print(f"\n OCR from {os.path.basename(img_path)}:\n{text[:300]}")  # preview
# Out:
#  OCR from page1_img1.png:
# S
#
# |
#
# Teachable Moments
#
#
#  OCR from page1_img2.png:
#
#
#  OCR from page1_img3.png:
#
#
#  OCR from page1_img4.png:
#
#
#  OCR from page1_img5.png:
#
#
#  OCR from page1_img6.png:
#
#
#  OCR from page1_img7.jpeg:
#
#
#  OCR from page1_img8.jpeg:
# Coral Seg
#
#
#
#  OCR from page1_img9.png:
#
#
#  OCR from page1_img10.png:
#
#
#  OCR from page1_img11.png:
#
#
#  OCR from page1_img12.png:
#
#
#  OCR from page1_img13.png:
#
#
#  OCR from page1_img14.png:
#
#
#  OCR from page1_img15.png:
#
#
#  OCR from page1_img16.png:
#
#
#  OCR from page1_img17.png:
#
#
#  OCR from page2_img1.png:
# S
#
# |
#
# Teachable Moments
#
#
#  OCR from page2_img2.jpeg:
#
#
#  OCR from page2_img3.png:
#
#
#  OCR from page2_img4.png:
#
#
#  OCR from page2_img5.png:
#
#
#  OCR from page2_img6.png:
#
#
#  OCR from page2_img7.png:
#
#
#  OCR from page2_img8.png:
#
#
#  OCR from page2_img9.jpeg:
#
#
#  OCR from page2_img10.png:
#
#
#  OCR from page2_img11.png:
#
#
#  OCR from page2_img12.png:
#
#
#  OCR from page2_img13.png:
#
#
#  OCR from page2_img14.png:
#
#
#  OCR from page2_img15.png:
#
#
#  OCR from page2_img16.png:
#
#
#  OCR from page3_img1.png:
# S
#
# |
#
# Teachable Moments
#
#
#  OCR from page3_img2.jpeg:
# 170.5°E 172,5°E
#
# 24.1°S
#
#
#
#  OCR from page3_img3.png:
#
#
#  OCR from page3_img4.png:
#
#
#  OCR from page3_img5.png:
#
#
#  OCR from page3_img6.png:
#
#
#  OCR from page3_img7.png:
#
#
#  OCR from page3_img8.png:
#
#
#  OCR from page3_img9.png:
# Not Fett
#
# Weak
#
# Light
#
# Moderate
#
# Strong
#
# Very Strong
#
# Severe
#
# Violent
#
# Extreme
#
# OK
#
# 68k
#
# 3k
#
# ok
#
# ok
#
# ok
#
# ok
#
# ok
#
#
#  OCR from page3_img10.png:
#
#
#  OCR from page3_img11.png:
#
#
#  OCR from page3_img12.png:
#
#
#  OCR from page3_img13.png:
#
#
#  OCR from page3_img14.png:
#
#
#  OCR from page3_img15.png:
#
#
#  OCR from page3_img16.png:
#
#
#  OCR from page4_img1.jpeg:
# oe S Wallis and ‘American
# ‘Samoa
#
# Niue
#
# New
# Caledonia
#
#
#  OCR from page4_img2.png:
# S
#
# |
#
# Teachable Moments
#
#
#  OCR from page4_img3.png:
#
#
#  OCR from page4_img4.png:
#
#
#  OCR from page4_img5.png:
#
#
#  OCR from page4_img6.png:
#
#
#  OCR from page4_img7.png:
#
#
#  OCR from page4_img8.png:
#
#
#  OCR from page4_img9.png:
#
#
#  OCR from page4_img10.png:
#
#
#  OCR from page4_img11.png:
#
#
#  OCR from page4_img12.jpeg:
# Depth
# (xm)
#
# 70
# 150
#
# 300
#
# 500
#
#
#  OCR from page4_img13.jpeg:
# Magnitude (Size)
#
# OS eeeec--
#
# 9 8 7654321
#
#
#  OCR from page4_img14.png:
#
#
#  OCR from page4_img15.jpeg:
# New
# Caledonia
#
#
#
#  OCR from page4_img16.png:
#
#
#  OCR from page4_img17.png:
#
#
#  OCR from page4_img18.png:
#
#
#  OCR from page4_img19.png:
#
#
#  OCR from page5_img1.png:
# S
#
# |
#
# Teachable Moments
#
#
#  OCR from page5_img2.jpeg:
# Caroline No. Bismark
# late Plate
#
# Pacific Plate
#
# emi,
#
# Balmoral Reef
#
#
#
#  OCR from page5_img3.png:
#
#
#  OCR from page5_img4.png:
#
#
#  OCR from page5_img5.png:
#
#
#  OCR from page5_img6.png:
#
#
#  OCR from page5_img7.png:
#
#
#  OCR from page5_img8.png:
#
#
#  OCR from page5_img9.png:
#
#
#  OCR from page5_img10.png:
#
#
#  OCR from page5_img11.png:
#
#
#  OCR from page5_img12.png:
#
#
#  OCR from page5_img13.png:
#
#
#  OCR from page5_img14.png:
#
#
#  OCR from page5_img15.png:
#
#
#  OCR from page6_img1.png:
# S
#
# |
#
# Teachable Moments
#
#
#  OCR from page6_img2.png:
#
#
#  OCR from page6_img3.png:
#
#
#  OCR from page6_img4.png:
#
#
#  OCR from page6_img5.png:
#
#
#  OCR from page6_img6.png:
#
#
#  OCR from page6_img7.png:
#
#
#  OCR from page6_img8.png:
#
#
#  OCR from page6_img9.png:
#
#
#  OCR from page6_img10.png:
#
#
#  OCR from page6_img11.png:
#
#
#  OCR from page6_img12.png:
#
#
#  OCR from page6_img13.png:
#
#
#  OCR from page6_img14.png:
#
#
#  OCR from page7_img1.png:
# S
#
# |
#
# Teachable Moments
#
#
#  OCR from page7_img2.png:
# Focal 2D Projection
# Block model Sphere of Focal Sphere
#
#
#  OCR from page7_img3.png:
#
#
#  OCR from page7_img4.png:
#
#
#  OCR from page7_img5.png:
#
#
#  OCR from page7_img6.png:
#
#
#  OCR from page7_img7.png:
#
#
#  OCR from page7_img8.png:
#
#
#  OCR from page7_img9.jpeg:
#
#
#  OCR from page7_img10.png:
# Reverse/Thrust/Compression
#
# eo
#
#
#
#  OCR from page7_img11.png:
#
#
#  OCR from page7_img12.png:
#
#
#  OCR from page7_img13.png:
#
#
#  OCR from page7_img14.png:
#
#
#  OCR from page7_img15.png:
#
#
#  OCR from page7_img16.png:
#
#
#  OCR from page7_img17.png:
#
#
#  OCR from page8_img1.png:
# S
#
# |
#
# Teachable Moments
#
#
#  OCR from page8_img2.png:
#
#
#  OCR from page8_img3.png:
#
#
#  OCR from page8_img4.png:
#
#
#  OCR from page8_img5.png:
#
#
#  OCR from page8_img6.png:
#
#
#  OCR from page8_img7.jpeg:
#
#
#  OCR from page8_img8.png:
#
#
#  OCR from page8_img9.png:
#
#
#  OCR from page8_img10.png:
#
#
#  OCR from page8_img11.png:
#
#
#  OCR from page8_img12.png:
#
#
#  OCR from page8_img13.png:
#
#
#  OCR from page8_img14.png:
#
#
#  OCR from page8_img15.png:
#
#
#  OCR from page9_img1.png:
# 110}
#
# 100}
#
# 80}
#
# 704
#
# 60}
#
# Degrees
#
# 50/
#
# 40}
#
# 304
#
# 204
#
# 10}
#
# Distance to Epicenter: 91.5°
# 10177 km
#
# T 1 1 1 1 T T T
# 00:05 00:10 00:15 00:20 00:25 00:30 00:35 00:40
# Time (Minutes)
#
# 1 1 rT T
# 00:45 00:50 00:55 01:00
#
#
#  OCR from page9_img2.png:
# S
#
# |
#
# Teachable Moments
#
#
#  OCR from page9_img3.png:
#
#
#  OCR from page9_img4.png:
#
#
#  OCR from page9_img5.png:
#
#
#  OCR from page9_img6.png:
#
#
#  OCR from page9_img7.png:
#
#
#  OCR from page9_img8.png:
#
#
#  OCR from page9_img9.png:
#
#
#  OCR from page9_img10.png:
#
#
#  OCR from page9_img11.png:
#
#
#  OCR from page9_img12.png:
#
#
#  OCR from page9_img13.png:
#
#
#  OCR from page9_img14.png:
#
#
#  OCR from page9_img15.png:
#
#
#  OCR from page10_img1.png:
# Ec]
# University lé
#
# of Portland
#
#
#  OCR from page10_img2.jpeg:
#
#
#  OCR from page10_img3.png:

# %% [markdown]
# Compiling Structured Output
# I combine the raw page text and OCR output into a dictionary, then save as JSON and CSV for easy consumption.

# %%
import json
import csv
import os

# 1. Ensure output directory exists
output_dir = "../output"
os.makedirs(output_dir, exist_ok=True)

# 2. Build a dictionary of selectable text for each page
page_texts = {}
for i in range(len(doc)):
    text = doc[i].get_text().strip()
    page_texts[i + 1] = text

# 3. Assume ocr_results is already populated as:
#    { page_number: [ocr_text_from_image1, ocr_text_from_image2, …], … }

# 4. Combine page text + OCR into a records list
records = []
for page in range(1, len(doc) + 1):
    records.append({
        "page": page,
        "text": page_texts.get(page, ""),
        "ocr":  "\n\n".join(ocr_results.get(page, []))
    })

# 5. Save to JSON
out_json = os.path.join(output_dir, "metadata_extraction.json")
with open(out_json, "w", encoding="utf-8") as f:
    json.dump(records, f, indent=2, ensure_ascii=False)
print(f" Saved structured output to {out_json}")

# 6. Save to CSV (truncating long fields for safety)
out_csv = os.path.join(output_dir, "metadata_extraction.csv")
with open(out_csv, "w", newline="", encoding="utf-8") as f:
    writer = csv.DictWriter(f, fieldnames=["page", "text", "ocr"])
    writer.writeheader()
    for rec in records:
        writer.writerow({
            "page": rec["page"],
            "text": rec["text"][:1000],
            "ocr":  rec["ocr"][:1000]
        })
print(f" Saved CSV summary to {out_csv}")
# Out:
#  Saved structured output to ../output\metadata_extraction.json
#  Saved CSV summary to ../output\metadata_extraction.csv

# %% [markdown]
# **Parse Key Metadata Fields**
#
# Now that I have both the PDF‑text (`page_texts`) and image‑OCR (`ocr_results`) for each page, I’ll:
#
# 1. Combine them into a single string per page.
# 2. Use regular expressions to extract:
#    - **Event date/time**
#    - **Magnitude**
#    - **Location coordinates**
#    - **Depth**
# 3. Build a Pandas DataFrame and inspect the results.

# %%
import re
import pandas as pd
import json

# 1. Load the structured JSON output
with open("../output/metadata_extraction.json", "r", encoding="utf-8") as f:
    records = json.load(f)

# 2. Define regex patterns
date_pat      = re.compile(r"(\d{4}-\d{2}-\d{2}T?\s*\d{2}:\d{2}:\d{2})")  # ISO or space‑separated
mag_pat       = re.compile(r"Magnitude[:\s]+([0-9]\.\d)")
loc_pat       = re.compile(r"\[?(-?\d+\.\d+),\s*(-?\d+\.\d+)\]?")         # [lat, lon]
depth_pat     = re.compile(r"depth.*?(\d+)\s*km", re.IGNORECASE)

# 3. Extract into a list of dicts
parsed = []
for rec in records:
    page = rec["page"]
    text = rec["text"] + "\n" + rec["ocr"]
    
    date_match  = date_pat.search(text)
    mag_match   = mag_pat.search(text)
    loc_match   = loc_pat.search(text)
    depth_match = depth_pat.search(text)
    
    parsed.append({
        "page":       page,
        "date":       date_match.group(1)    if date_match   else None,
        "magnitude":  float(mag_match.group(1)) if mag_match  else None,
        "latitude":   float(loc_match.group(1)) if loc_match  else None,
        "longitude":  float(loc_match.group(2)) if loc_match  else None,
        "depth_km":   int(depth_match.group(1)) if depth_match else None
    })

# 4. Create DataFrame
df_meta = pd.DataFrame(parsed)
df_meta
# Out:
#    page  date  magnitude latitude longitude  depth_km
# 0     1  None        7.0     None      None      10.0
# 1     2  None        7.0     None      None       NaN
# 2     3  None        7.0     None      None       NaN
# 3     4  None        7.0     None      None       NaN
# 4     5  None        7.0     None      None       NaN
# 5     6  None        7.0     None      None       NaN
# 6     7  None        7.0     None      None       NaN
# 7     8  None        7.0     None      None       NaN
# 8     9  None        7.0     None      None       NaN
# 9    10  None        NaN     None      None       NaN

# %%
# Display the dataframe (in Jupyter this will render nicely)
df_meta

# Save to CSV
df_meta.to_csv("../output/parsed_seismic_metadata.csv", index=False)
df_check = pd.read_csv("../output/parsed_seismic_metadata.csv")
print(df_check.head())  # Display the first few rows to verify
# Out:
#    page  date  magnitude  latitude  longitude  depth_km
# 0     1   NaN        7.0       NaN        NaN      10.0
# 1     2   NaN        7.0       NaN        NaN       NaN
# 2     3   NaN        7.0       NaN        NaN       NaN
# 3     4   NaN        7.0       NaN        NaN       NaN
# 4     5   NaN        7.0       NaN        NaN       NaN
